# %% [markdown]
# <a href="https://colab.research.google.com/github/KUGAN123/KUGAN123/blob/main/project_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/product_defects-1.csv")

# %%
df.head()
# Out:
#         image_id  pixel_variance  color_deviation  is_defective
# 0  prod_0000.jpg       46.841947         5.038350             0
# 1  prod_0001.jpg       49.023405         6.911109             0
# 2  prod_0002.jpg       32.122725         4.403620             0
# 3  prod_0003.jpg       54.580532         5.930063             0
# 4  prod_0004.jpg       59.631456         7.451102             0

# %%
df.head(10)
# Out:
#         image_id  pixel_variance  color_deviation  is_defective
# 0  prod_0000.jpg       46.841947         5.038350             0
# 1  prod_0001.jpg       49.023405         6.911109             0
# 2  prod_0002.jpg       32.122725         4.403620             0
# 3  prod_0003.jpg       54.580532         5.930063             0
# 4  prod_0004.jpg       59.631456         7.451102             0
# 5  prod_0005.jpg       50.728020         3.562698             0
# 6  prod_0006.jpg       49.677461         1.206642             0
# 7  prod_0007.jpg       35.472826         7.268120             0
# 8  prod_0008.jpg       38.448384         1.320466             0
# 9  prod_0009.jpg       37.910504         5.942113             0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['pixel_variance'].plot(kind='hist', bins=20, title='pixel_variance')
# ...

# %%
# prompt: Using dataframe df: pixel_variance between color_deviation	average visualization bar chart

import altair as alt
# Create a bar chart showing the relationship between pixel_variance and color_deviation
chart = alt.Chart(df).mark_bar().encode(
    x='pixel_variance',  # Use pixel_variance for the x-axis
    y='color_deviation'  # Use color_deviation for the y-axis
)
# Display the chart
chart
# Out:
# alt.Chart(...)
